# %% [markdown]
# GOKUL SHANTHOSH M
# 192124203
# SALES DATA ANALYSIS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df= pd.read_csv('/content/drive/MyDrive/superstore_final_dataset (1).csv',encoding='windows-1252')

# %%
df.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156  08-11-2017  11-11-2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08-11-2017  11-11-2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12-06-2017  16-06-2017    Second Class    DV-13045
# 3       4  US-2016-108966  11-10-2016  18-10-2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11-10-2016  18-10-2016  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
# 4    Sean O Donnel   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.tail()
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 9795    9796  CA-2017-125920  21-05-2017  28-05-2017  Standard Class
# 9796    9797  CA-2016-128608  12-01-2016  17-01-2016  Standard Class
# 9797    9798  CA-2016-128608  12-01-2016  17-01-2016  Standard Class
# 9798    9799  CA-2016-128608  12-01-2016  17-01-2016  Standard Class
# 9799    9800  CA-2016-128608  12-01-2016  17-01-2016  Standard Class
#
#      Customer_ID     Customer_Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal_Code   Region       Product_ID         Category  \
# ...

# %%
df.tail()
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 9795    9796  CA-2017-125920  21-05-2017  28-05-2017  Standard Class
# 9796    9797  CA-2016-128608  12-01-2016  17-01-2016  Standard Class
# 9797    9798  CA-2016-128608  12-01-2016  17-01-2016  Standard Class
# 9798    9799  CA-2016-128608  12-01-2016  17-01-2016  Standard Class
# 9799    9800  CA-2016-128608  12-01-2016  17-01-2016  Standard Class
#
#      Customer_ID     Customer_Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal_Code   Region       Product_ID         Category  \
# ...

# %%
df.loc[20:25]
# Out:
#     Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 20      21  CA-2015-143336  27-08-2015  01-09-2015    Second Class
# 21      22  CA-2017-137330  09-12-2017  13-12-2017  Standard Class
# 22      23  CA-2017-137330  09-12-2017  13-12-2017  Standard Class
# 23      24  US-2018-156909  16-07-2018  18-07-2018    Second Class
# 24      25  CA-2016-106320  25-09-2016  30-09-2016  Standard Class
# 25      26  CA-2017-121755  16-01-2017  20-01-2017    Second Class
#
#    Customer_ID       Customer_Name    Segment        Country           City  \
# 20    ZD-21925  Zuschuss Donatelli   Consumer  United States  San Francisco
# 21    KB-16585           Ken Black  Corporate  United States        Fremont
# 22    KB-16585           Ken Black  Corporate  United States        Fremont
# 23    SF-20065     Sandra Flanagan   Consumer  United States   Philadelphia
# 24    EB-13870         Emily Burns   Consumer  United States           Orem
# ...

# %%
df.describe()
# Out:
#             Row_ID   Postal_Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9800 non-null   int64
#  1   Order_ID       9800 non-null   object
#  2   Order_Date     9800 non-null   object
#  3   Ship_Date      9800 non-null   object
#  4   Ship_Mode      9800 non-null   object
#  5   Customer_ID    9800 non-null   object
#  6   Customer_Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal_Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product_ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub_Category   9800 non-null   object
#  16  Product_Name   9800 non-null   object
# ...

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.isna().sum()
# Out:
# Row_ID            0
# Order_ID          0
# Order_Date        0
# Ship_Date         0
# Ship_Mode         0
# Customer_ID       0
# Customer_Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal_Code      11
# Region            0
# Product_ID        0
# Category          0
# Sub_Category      0
# Product_Name      0
# Sales             0
# dtype: int64

# %%
import missingno as msno
msno.matrix(df);

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['Region'].value_counts()
# Out:
# West       3140
# East       2785
# Central    2277
# South      1598
# Name: Region, dtype: int64

# %%
df['Region'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df['Ship_Mode'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df['Segment'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
top_selling_products= df.groupby(["Product_Name"]).sum()["Sales"].sort_values(ascending=False)

# %%
top_selling_products
# Out:
# Product_Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
#                                                                                  ...
# Acme Serrated Blade Letter Opener                                                  7.632
# Grip Seal Envelopes                                                                7.072
# Xerox 20                                                                           6.480
# Avery 5                                                                            5.760
# ...

# %%
top_5_selling_products = top_selling_products.head()

# %%
fig, (ax1) = plt.subplots(1 , figsize=(15,5))


top_5_selling_products.plot(kind="bar", y="Sales", ax=ax1)
ax1.set_title("Top 5 Selling Products")

plt.show()

# %%
least_selling_products= df.groupby(["Product_Name"]).sum()["Sales"].sort_values(ascending=False)

least_5_selling_products = least_selling_products.tail()
print(least_5_selling_products)

fig, (ax1) = plt.subplots(1 , figsize=(15,5))


least_5_selling_products.plot(kind="bar",x="Product_Name", y="Sales", ax=ax1)
ax1.set_title("Least 5 Selling Products")

plt.show()
# Out:
# Product_Name
# Acme Serrated Blade Letter Opener                                   7.632
# Grip Seal Envelopes                                                 7.072
# Xerox 20                                                            6.480
# Avery 5                                                             5.760
# Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac    1.624
# Name: Sales, dtype: float64

# %%
panasonic_on_East_region = df[(df["Product_Name"] == "Panasonic Kx-TS550")&(df["Region"]=="East")]

panasonic_on_East_region['Sales'].plot(kind="bar")
plt.show()

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df_places = df[['City','State','Region','Sales']]

# %%
grouped_data = df_places.groupby(['Region'], as_index=False).sum()
grouped_data.sort_values(by='Sales', ascending=False, inplace=True)

plt.figure(figsize=(10,5))
plt.bar(grouped_data['Region'], grouped_data['Sales'], align='center',)
plt.title("Sales Generated by Region")
plt.xlabel("Region")
plt.ylabel("Sales")


plt.show()

# %%
grouped_data = df_places.groupby(['State'], as_index=False).sum()
grouped_data.sort_values(by='Sales', ascending=False, inplace=True)

plt.figure(figsize=(16,8))
plt.bar(grouped_data['State'], grouped_data['Sales'], align='center',)
plt.xlabel("State")
plt.ylabel("Sales")
plt.title("Sales Generated by State")
plt.xticks(rotation=90)

plt.show()

# %%
top_cities = df.groupby("City")["Sales"].sum().nlargest(10)

plt.figure(figsize=(8, 6))

top_cities.plot(kind="bar", color="red")
plt.xlabel("City")
plt.ylabel("Sales Amount")
plt.title("Top 10 Cities with Highest Sales", color="Blue")
plt.xticks(rotation=45)

plt.show()

# %%
df_relations = df[['Ship_Mode','Sales']]

# %%
Ship_Mode_Sales_Profit = df_relations.groupby(['Ship_Mode']).sum().reset_index(False)
Ship_Mode_Sales_Profit =Ship_Mode_Sales_Profit.sort_values('Sales', ascending=False)

plt.figure(figsize=(10,15))
plt.subplot(3,1,1)
plt.bar(x=Ship_Mode_Sales_Profit['Ship_Mode'], height=Ship_Mode_Sales_Profit['Sales'], color='Green')
plt.title("relationship between ship mode and sales", size=20, pad=20)


plt.show()

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], format='%d-%m-%Y')

df['Year'] = df['Order_Date'].dt.year

target_year = 2017

df_target_year = df[df['Year'] == target_year]

product_sales = df_target_year.groupby('Product_Name')['Sales'].sum().reset_index()

top_selling_products = product_sales.sort_values(by='Sales', ascending=False)

print("Top Selling Products in", target_year)
print(top_selling_products)

plt.figure(figsize=(10, 6))
plt.bar(top_selling_products['Product_Name'][:10], top_selling_products['Sales'][:10], color='skyblue')
plt.xlabel('Product Name')
plt.ylabel('Total Sales')
plt.title(f'Top 10 Selling Products in {target_year}')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Top Selling Products in 2017
#                                           Product_Name      Sales
# 301              Canon imageCLASS 2200 Advanced Copier  25899.926
# 506   GBC Ibimaster 500 Manual ProClick Binding System  12860.562
# 13    3D Systems Cube Printer, 2nd Generation, Magenta   9099.930
# 608        High Speed Automatic Electric Letter Opener   8842.662
# 592  HP Designjet T520 Inkjet Large Format Printer ...   8749.950
# ..                                                 ...        ...
# 39                     Acco Bankers Clasps, 5 3/4-Long      2.304
# 785                          Maxell 4.7GB DVD+R 5/Pack      1.980
# 179                              Avery Durable Binders      1.728
# 874                        OIC #2 Pencils, Medium Soft      1.504
# 824                                         Newell 310      1.408
#
# [1350 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['Order_Date'] = pd.to_datetime(df['Order_Date'], format='%d-%m-%Y')

df['Year'] = df['Order_Date'].dt.year

target_year = 2017

df_target_year = df[df['Year'] == target_year]

product_sales = df_target_year.groupby('Product_Name')['Sales'].sum().reset_index()

least_selling_products = product_sales.sort_values(by='Sales', ascending=True)

print("Least Selling Products in", target_year)
print(least_selling_products.head(10))

plt.figure(figsize=(10, 6))
plt.bar(least_selling_products['Product_Name'][:10], least_selling_products['Sales'][:10], color='lightcoral')
plt.xlabel('Product Name')
plt.ylabel('Total Sales')
plt.title(f'Least 10 Selling Products in {target_year}')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Least Selling Products in 2017
#                                     Product_Name  Sales
# 824                                   Newell 310  1.408
# 874                  OIC #2 Pencils, Medium Soft  1.504
# 179                        Avery Durable Binders  1.728
# 785                    Maxell 4.7GB DVD+R 5/Pack  1.980
# 39               Acco Bankers Clasps, 5 3/4-Long  2.304
# 144                                    Avery 479  2.610
# 35                             Acco 3-Hole Punch  2.628
# 432  Eldon Spacemaker Box, Quick-Snap Lid, Clear  2.672
# 833                                    Newell 32  2.880
# 145                                    Avery 480  3.000

# %%
customer_products = df.groupby('Customer_Name')['Product_Name'].unique().reset_index()

print("Customers and their Bought Products:")
for index, row in customer_products.sample(5).iterrows():
    customer_name = row['Customer_Name']
    bought_products = row['Product_Name']
    print(f"{customer_name} bought the following products:")
    for product in bought_products:
        print(f"- {product}")
    print()
# Out:
# Customers and their Bought Products:
# Sample Company A bought the following products:
# - 3M Hangers With Command Adhesive
# - Flexible Leather- Look Classic Collection Ring Binder
# - Ooma Telo VoIP Home Phone System
# - 9-3/4 Diameter Round Wall Clock
# - AT&T 1080 Phone
# - Easy-staple paper
# - Square Ring Data Binders, Rigid 75 Pt. Covers, 11 x 14-7/8
# - Kensington Expert Mouse Optical USB Trackball for PC or Mac
# - Eldon Cleatmat Chair Mats for Medium Pile Carpets
# - Swingline SM12-08 MicroCut Jam Free Shredder
# - Tennsco 6- and 18-Compartment Lockers
# - GBC Instant Report Kit
# - OSullivan Cherrywood Estates Traditional Bookcase
# - Tops Wirebound Message Log Books
# - Fellowes Advanced Computer Series Surge Protectors
#
# Joe Kamberova bought the following products:
# - Cisco Unified IP Phone 7945G VoIP phone
# - Xerox 1910
# - Logitech G500s Laser Gaming Mouse with Adjustable Weight Tuning
# - Premium Transparent Presentation Covers by GBC
# ...

# %%
customer_product_count = df.groupby('Customer_Name')['Product_Name'].nunique().reset_index()

top_buying_customers = customer_product_count.sort_values(by='Product_Name', ascending=False)

most_products_customer = top_buying_customers.iloc[0]['Customer_Name']
print(f"The customer who bought the most products is: {most_products_customer}")

plt.figure(figsize=(10, 6))
plt.bar(top_buying_customers['Customer_Name'][:10], top_buying_customers['Product_Name'][:10], color='green')
plt.xlabel('Customer Name')
plt.ylabel('Number of Products Bought')
plt.title('Top 10 Customers Buying the Most Products')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# The customer who bought the most products is: Paul Prost

# %%
customer_order_count = df.groupby('Customer_Name')['Order_ID'].nunique().reset_index()

top_regular_customers = customer_order_count.sort_values(by='Order_ID', ascending=False)

print("Top Regular Customers:")
print(top_regular_customers.head(10))

plt.figure(figsize=(10, 6))
plt.bar(top_regular_customers['Customer_Name'][:10], top_regular_customers['Order_ID'][:10], color='orange')
plt.xlabel('Customer Name')
plt.ylabel('Number of Orders Placed')
plt.title('Top 10 Regular Customers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Top Regular Customers:
#            Customer_Name  Order_ID
# 259           Emily Phan        17
# 145  Chloris Kastensmidt        13
# 381           Joel Eaton        13
# 791     Zuschuss Carroll        13
# 586      Patrick Gardner        13
# 603            Pete Kriz        12
# 437            Ken Black        12
# 329        Henry Goldwyn        12
# 169          Clay Ludtke        12
# 87        Bill Donatelli        12

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], format='%d-%m-%Y')

df['Year'] = df['Order_Date'].dt.year

customer_product_count_yearly = df.groupby(['Year', 'Customer_Name'])['Product_Name'].nunique().reset_index()

top_customers_yearly = customer_product_count_yearly.loc[customer_product_count_yearly.groupby('Year')['Product_Name'].idxmax()]

print("Top Customers Year-wise:")
print(top_customers_yearly)

for year in df['Year'].unique():
    top_customers_year = top_customers_yearly[top_customers_yearly['Year'] == year]
    plt.figure(figsize=(10, 6))
    plt.bar(top_customers_year['Customer_Name'], top_customers_year['Product_Name'], color='purple')
    plt.xlabel('Customer Name')
    plt.ylabel('Number of Products Bought')
    plt.title(f'Top Customer(s) in {year} Who Bought the Most Products')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# Top Customers Year-wise:
#       Year     Customer_Name  Product_Name
# 494   2015        Sam Craven            16
# 1023  2016      Peter Fuller            16
# 1473  2017  Jonathan Doherty            21
# 2391  2018       Seth Vernon            20

# %%
customer_product_count_region = df.groupby(['Region', 'Customer_Name'])['Product_Name'].nunique().reset_index()

top_customers_region = customer_product_count_region.loc[customer_product_count_region.groupby('Region')['Product_Name'].idxmax()]

print("Top Customers Region-wise:")
print(top_customers_region)

for region in df['Region'].unique():
    top_customers_region_year = top_customers_region[top_customers_region['Region'] == region]
    plt.figure(figsize=(10, 6))
    plt.bar(top_customers_region_year['Customer_Name'], top_customers_region_year['Product_Name'], color='brown')
    plt.xlabel('Customer Name')
    plt.ylabel('Number of Products Bought')
    plt.title(f'Top Customer(s) in {region} Region Who Bought the Most Products')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# Top Customers Region-wise:
#        Region  Customer_Name  Product_Name
# 341   Central   Ken Lonsdale            17
# 1209     East    Seth Vernon            25
# 1324    South  Anna Häberlin            13
# 2479     West  William Brown            23

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], format='%d-%m-%Y')

df['Year'] = df['Order_Date'].dt.year.astype(int)

yearly_sales = df.groupby('Year')['Sales'].sum().reset_index()

max_sales_year = yearly_sales.loc[yearly_sales['Sales'].idxmax()]

print("Year with the Highest Sales:")
print(max_sales_year)

plt.figure(figsize=(10, 6))
plt.bar(yearly_sales['Year'], yearly_sales['Sales'], color='blue')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.title('Total Sales in Each Year')
plt.xticks(yearly_sales['Year'].astype(int), rotation=45, ha='right')
plt.show()
# Out:
# Year with the Highest Sales:
# Year       2018.0000
# Sales    722052.0192
# Name: 3, dtype: float64
